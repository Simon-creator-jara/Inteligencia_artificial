# %% [markdown]
# <a href="https://colab.research.google.com/github/Simon-creator-jara/Inteligencia_artificial/blob/main/Arboles_decision_Duvan_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Arbol de clasificación 
##Importar librerías 
#Tratamiento de datos 
import numpy as np
import pandas as pd
import statsmodels.api as sm

#Graficos
import matplotlib.pyplot as plt

#Procesamiento y modelado 
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier 
from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz
from sklearn.tree import export_text
from sklearn.compose import ColumnTransformer 
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

#Advertencias
import warnings
warnings.filterwarnings('ignore')

# %%
datos= pd.read_csv('Lending_club_cleaned_2.csv')
datos.head()
# Out:
#    loan_status  annual_inc verification_status emp_length home_ownership  \
# 0   Fully Paid     24000.0            Verified  10+ years           RENT
# 1  Charged Off     30000.0     Source Verified   < 1 year           RENT
# 2   Fully Paid     12252.0        Not Verified  10+ years           RENT
# 3   Fully Paid     49200.0     Source Verified  10+ years           RENT
# 4   Fully Paid     80000.0     Source Verified     1 year           RENT
#
#   int_rate  loan_amnt         purpose        term grade
# 0   10.65%       5000     credit_card   36 months     B
# 1   15.27%       2500             car   60 months     C
# 2   15.96%       2400  small_business   36 months     C
# 3   13.49%      10000           other   36 months     C
# 4   12.69%       3000           other   60 months     B

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38705 entries, 0 to 38704
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   loan_status          38705 non-null  object
#  1   annual_inc           38705 non-null  float64
#  2   verification_status  38705 non-null  object
#  3   emp_length           38705 non-null  object
#  4   home_ownership       38705 non-null  object
#  5   int_rate             38705 non-null  object
#  6   loan_amnt            38705 non-null  int64
#  7   purpose              38705 non-null  object
#  8   term                 38705 non-null  object
#  9   grade                38705 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 3.0+ MB

# %%
datos.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7facda6cee10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7facda84a850>]],
#       dtype=object)

# %%
datos['loan_status_def']=np.where(datos.loan_status == 'Fully Paid',1,0)

# %%
datos.head()
# Out:
#    loan_status  annual_inc verification_status emp_length home_ownership  \
# 0   Fully Paid     24000.0            Verified  10+ years           RENT
# 1  Charged Off     30000.0     Source Verified   < 1 year           RENT
# 2   Fully Paid     12252.0        Not Verified  10+ years           RENT
# 3   Fully Paid     49200.0     Source Verified  10+ years           RENT
# 4   Fully Paid     80000.0     Source Verified     1 year           RENT
#
#   int_rate  loan_amnt         purpose        term grade  loan_status_def
# 0   10.65%       5000     credit_card   36 months     B                1
# 1   15.27%       2500             car   60 months     C                0
# 2   15.96%       2400  small_business   36 months     C                1
# 3   13.49%      10000           other   36 months     C                1
# 4   12.69%       3000           other   60 months     B                1

# %%
datos=datos.drop(columns='loan_status')

# %%
datos.head()
# Out:
#    annual_inc verification_status emp_length home_ownership int_rate  \
# 0     24000.0            Verified  10+ years           RENT   10.65%
# 1     30000.0     Source Verified   < 1 year           RENT   15.27%
# 2     12252.0        Not Verified  10+ years           RENT   15.96%
# 3     49200.0     Source Verified  10+ years           RENT   13.49%
# 4     80000.0     Source Verified     1 year           RENT   12.69%
#
#    loan_amnt         purpose        term grade  loan_status_def
# 0       5000     credit_card   36 months     B                1
# 1       2500             car   60 months     C                0
# 2       2400  small_business   36 months     C                1
# 3      10000           other   36 months     C                1
# 4       3000           other   60 months     B                1

# %%
datos_dummies=pd.get_dummies(datos)

# %%
datos.groupby('loan_status_def')['loan_status_def'].count()
# Out:
# loan_status_def
# 0     5440
# 1    33265
# Name: loan_status_def, dtype: int64

# %%
import re

# %%
datos['int_rate']=datos['int_rate'].apply(lambda x: re.findall('[0-9]',x))

# %%
datos['int_rate']=datos['int_rate'].apply(lambda x: int("".join(x))/100)

# %%
xEntrenamiento, xPrueba, yEntrenamiento, yPrueba = train_test_split(datos.drop(columns='loan_status_def'),
                                                                    datos['loan_status_def'],
                                                                    train_size=0.7,
                                                                    random_state=123)

# %%
#Codificar variables categóricas
catCol = xEntrenamiento.select_dtypes(include= ['object','category'] ).columns.to_list()
numCol = xEntrenamiento.select_dtypes(include= ['float64','int64'] ).columns.to_list()

preprocesador = ColumnTransformer([('onehot', OneHotEncoder(handle_unknown = 'ignore'),catCol)],remainder = 'passthrough')


xEntrenamientoPre =preprocesador.fit_transform(xEntrenamiento)
xPruebaPre = preprocesador.fit_transform(xPrueba)

# %%
codCat=preprocesador.named_transformers_['onehot'].get_feature_names(catCol)
labels = np.concatenate([codCat,numCol])

xEntrenamientoProc = pd.DataFrame.sparse.from_spmatrix(xEntrenamientoPre, columns=labels)
xPruebaProc = pd.DataFrame.sparse.from_spmatrix(xPruebaPre, columns=labels)

xEntrenamientoProc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27093 entries, 0 to 27092
# Data columns (total 44 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   verification_status_Not Verified     27093 non-null  Sparse[float64, 0]
#  1   verification_status_Source Verified  27093 non-null  Sparse[float64, 0]
#  2   verification_status_Verified         27093 non-null  Sparse[float64, 0]
#  3   emp_length_1 year                    27093 non-null  Sparse[float64, 0]
#  4   emp_length_10+ years                 27093 non-null  Sparse[float64, 0]
#  5   emp_length_2 years                   27093 non-null  Sparse[float64, 0]
#  6   emp_length_3 years                   27093 non-null  Sparse[float64, 0]
#  7   emp_length_4 years                   27093 non-null  Sparse[float64, 0]
#  8   emp_length_5 years                   27093 non-null  Sparse[float64, 0]
#  9   emp_length_6 years                   27093 non-null  Sparse[float64, 0]
#  10  emp_length_7 years                   27093 non-null  Sparse[float64, 0]
#  11  emp_length_8 years                   27093 non-null  Sparse[float64, 0]
#  12  emp_length_9 years                   27093 non-null  Sparse[float64, 0]
#  13  emp_length_< 1 year                  27093 non-null  Sparse[float64, 0]
#  14  home_ownership_MORTGAGE              27093 non-null  Sparse[float64, 0]
#  15  home_ownership_OTHER                 27093 non-null  Sparse[float64, 0]
#  16  home_ownership_OWN                   27093 non-null  Sparse[float64, 0]
#  17  home_ownership_RENT                  27093 non-null  Sparse[float64, 0]
#  18  purpose_car                          27093 non-null  Sparse[float64, 0]
#  19  purpose_credit_card                  27093 non-null  Sparse[float64, 0]
#  20  purpose_debt_consolidation           27093 non-null  Sparse[float64, 0]
#  21  purpose_educational                  27093 non-null  Sparse[float64, 0]
#  22  purpose_home_improvement             27093 non-null  Sparse[float64, 0]
#  23  purpose_house                        27093 non-null  Sparse[float64, 0]
#  24  purpose_major_purchase               27093 non-null  Sparse[float64, 0]
#  25  purpose_medical                      27093 non-null  Sparse[float64, 0]
#  26  purpose_moving                       27093 non-null  Sparse[float64, 0]
#  27  purpose_other                        27093 non-null  Sparse[float64, 0]
#  28  purpose_renewable_energy             27093 non-null  Sparse[float64, 0]
#  29  purpose_small_business               27093 non-null  Sparse[float64, 0]
#  30  purpose_vacation                     27093 non-null  Sparse[float64, 0]
#  31  purpose_wedding                      27093 non-null  Sparse[float64, 0]
#  32  term_ 36 months                      27093 non-null  Sparse[float64, 0]
#  33  term_ 60 months                      27093 non-null  Sparse[float64, 0]
#  34  grade_A                              27093 non-null  Sparse[float64, 0]
#  35  grade_B                              27093 non-null  Sparse[float64, 0]
#  36  grade_C                              27093 non-null  Sparse[float64, 0]
#  37  grade_D                              27093 non-null  Sparse[float64, 0]
#  38  grade_E                              27093 non-null  Sparse[float64, 0]
#  39  grade_F                              27093 non-null  Sparse[float64, 0]
#  40  grade_G                              27093 non-null  Sparse[float64, 0]
#  41  annual_inc                           27093 non-null  Sparse[float64, 0]
#  42  int_rate                             27093 non-null  Sparse[float64, 0]
#  43  loan_amnt                            27093 non-null  Sparse[float64, 0]
# dtypes: Sparse[float64, 0](44)
# memory usage: 2.8 MB

# %%
#Modelar los datos 
modelo = DecisionTreeClassifier(max_depth=10,
                                criterion='gini',
                                random_state=123)

# %%
modelo.fit(xEntrenamientoProc,yEntrenamiento)
# Out:
# DecisionTreeClassifier(max_depth=10, random_state=123)

# %%
fig,ax=plt.subplots(figsize=(16,9))
print(f"Profundidad del arbol: {modelo.get_depth()}")
print(f"Número de nodos terminales: {modelo.get_n_leaves()}")

plot = plot_tree(decision_tree = modelo,
                feature_names = labels.tolist(),
                class_names='ventasAltas',
                filled=True,
                impurity=False,
                fontsize=7,
                ax=ax)
# Out:
# Profundidad del arbol: 10
# Número de nodos terminales: 460

# %%
#Desempeño en entrenamiento 
accuracyEnt = accuracy_score(y_true= yEntrenamiento,
                             y_pred=modelo.predict(xEntrenamientoProc))

print(f"El dedsempeño en entrenamiento es:{accuracyEnt}")
# Out:
# El dedsempeño en entrenamiento es:0.8735466725722512

# %%
#Matriz ed confusión en entrenamiento 
print('Matriz de confusión')
print('----------------------------------------')
confusion_matrix(y_true = yEntrenamiento,
                 y_pred=modelo.predict(xEntrenamientoProc))
# Out:
# Matriz de confusión
# ----------------------------------------
# array([[  532,  3296],
#        [  130, 23135]])

# %%
##Evaluar el modelo  en prueba
predicciones = modelo.predict(xPruebaProc)
#Matriz ed confusión en entrenamiento 
print('Matriz de confusión')
print('----------------------------------------')
confusion_matrix(y_true = yPrueba,
                 y_pred=predicciones)
# Out:
# Matriz de confusión
# ----------------------------------------
# array([[  85, 1527],
#        [ 235, 9765]])

# %%
#Desempeño en entrenamiento 
accuracyEnt = accuracy_score(y_true= yPrueba,
                             y_pred=modelo.predict(xPruebaProc))

print(f"El dedsempeño en entrenamiento es:{accuracyEnt}")
# Out:
# El dedsempeño en entrenamiento es:0.8482604202549087
